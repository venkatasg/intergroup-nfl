# %%
import pandas as pd
import random
import numpy as np
from tqdm import tqdm
import ipdb
import re
from glob import glob
import json
import csv
import datetime as dt
from collections import Counter

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('chained_assignment',None)

# Set random seeds for reproducibility on a specific machine
random.seed(1)
np.random.seed(1)
np.random.RandomState(1)

tqdm.pandas()

# nlp = stanza.Pipeline(lang='en', processors='tokenize')

# %%
sample = pd.read_csv('../data/wp/test_data.tsv', sep='\t', index_col=None, header=0, quoting=csv.QUOTE_NONE, escapechar="\\", engine='python')
sample.shape
# Out:
# (1499, 17)

# %%
postinfo = pd.read_csv('../data/postInfo.tsv', sep='\t')
gameinfo = pd.read_csv('../data/gameInfo.tsv', sep='\t')
postinfo.shape, gameinfo.shape
# Out:
# ((2407, 4), (569, 8))

# %%
teaminfo = pd.read_csv('../data/nfl_teams.csv')
teaminfo['team_name_short'] = teaminfo['team_name_short'].apply(lambda x: x.lower())

teams = teaminfo['team_name_short'].values.tolist()
subreddits = teaminfo['subreddit'].values.tolist()

teams_to_subreddit = {teams[i]: subreddits[i] for i in range(32)}
subreddit_to_teams = {subreddits[i]: teams[i] for i in range(32)}

# %%
df = pd.read_csv('../data/game_comments.tsv', sep='\t', index_col=None, header=0, quoting=csv.QUOTE_NONE, escapechar="\\", engine='python')

# Some cleanup
df['clean_comment'] = df['clean_comment'].astype(str)
df.loc[df['opp']=='commanders', 'opp'] = 'washington'

# %%
pbp = pd.read_csv('../data/play_by_play.tsv', sep='\t', low_memory=False)

def get_utc_timestamp(row):
    tod = row['time_of_day']
    date = row['game_date']
    
    day = int(date.split('-')[2])
    month = int(date.split('-')[1])
    year = int(date.split('-')[0])
    
    hour = int(tod.split(':')[0])
    minute = int(tod.split(':')[1])
    second = int(tod.split(':')[2])
    
    # UTC time for NFL games is almost always afternoon? The earliest local time is around 11am, which would be at least 3pm in UTC
    if int(hour)<12: 
        day_obj = dt.date(year, month, day)
        day = (day_obj + dt.timedelta(days=1)).day
    
    timestamp = dt.datetime(year, month, day, hour, minute, second, tzinfo=dt.timezone.utc)
    return int(timestamp.timestamp())

# %%
def find_parent(parent_id, post_id):
    if parent_id[:2]=='t3':
        return "No parent comment."
    else:
        parent_comment = df[((df['post_id']==post_id) & (df['comment_id']==parent_id[3:]))]['clean_comment']
        if parent_comment.shape[0]>0:
            parent_comment = parent_comment.values[0]
        else:
            "No parent comment."
        return parent_comment

# %%
def make_context(row):
    team = row['team'].title()
    opp = row['opp'].title()
    
    gameid = postinfo[postinfo['post_id'] == row['post_id']]['game_id'].values[0]
    game_pbp = pbp.loc[pbp['new_game_id']==gameid, ['game_date','time_of_day','posteam', 'home_team', 'away_team', 'total_home_score', 'total_away_score']].reset_index(drop=True)
    game_pbp = game_pbp.bfill().ffill()
    game_pbp['timestamp'] = game_pbp.apply(lambda x: get_utc_timestamp(x), axis=1)
    
    home_team, away_team = game_pbp['home_team'].values[0], game_pbp['away_team'].values[0]
    home_team = teaminfo.loc[teaminfo.team_id==home_team, 'team_name_short'].values[0].title()
    away_team = teaminfo.loc[teaminfo.team_id==away_team, 'team_name_short'].values[0].title()

    date = game_pbp.game_date.values[0]
    parent_comment = find_parent(row.parent_id, row.post_id)
    
    if row.timestamp > game_pbp.timestamp.min():
        home_score, away_score = game_pbp.loc[game_pbp.timestamp<row.timestamp, 'total_home_score'].values[-1], game_pbp.loc[game_pbp.timestamp<row.timestamp, 'total_away_score'].values[-1]
    else:
        home_score, away_score = 0, 0
        
    result =  home_team + ' ' + str(home_score) + '-' + str(away_score) + ' ' + away_team
    
    context = "**IN-GROUP**: " + team  + " || **OUT-GROUP**: " + opp + " || **LIVE-SCORE**: " + result + " || **GAME-DATE**: " + str(date) + " || **PARENT COMMENT**: " + parent_comment
    
    return context

sample['context'] = sample.progress_apply(lambda x: make_context(x), axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1499/1499 [06:37<00:00,  3.77it/s]

# %%
final = sample.loc[:, ['split', 'post_id', 'comment_id', 'tokenized_comment', 'context']]
final = final.rename(columns={"tokenized_comment": "source"}).loc[final.split=='test']

# %%
final
# Out:
#      split post_id comment_id  \
# 1     test  pu79mu    he18r6i
# 10    test  z0937l    ix4sj2p
# 17    test  xbm6x0    io146xc
# 18    test  pnqrqd    hcrtr5l
# 22    test  x9gwgf    inoabnj
# ...    ...     ...        ...
# 1475  test  ybqjnm    iti6k03
# 1476  test  zizm2a    iztpjpb
# 1481  test  z3yb3a    ixp28r0
# 1483  test  sah8rz    htu3x0j
# 1489  test  xitesl    ip5ez9f
#
#                                                                                                                                                                                             source  \
# 1                                                                                                                                  [SENT] Is it me or is this game fiery and fast paced tonight ?
# 10                                                                                                                                                      [SENT] This team implodes in the red zone
# 17                                                                                                                                                      [SENT] The Jets really are the Jetsiest .
# 18    [SENT] Ruggs has the potential to be an all time bust especially if Lamb and Juedy stay on their rise Such a bad pick . [SENT] Ferell and Ruggs are potentially franchise altering mistakes
# 22                                                                               [SENT] Ankle . [SENT] He ’s walking around in pads . [SENT] He was almost better than Miller in the first half .
# ...                                                                                                                                                                                            ...
# 1475                                                                                         [SENT] Ah , they finally called the MASSIVE holding going on . [SENT] Fourth times a charm I guess .
# 1476                                                                      [SENT] Anyone have a clip of the hit on Huntley ? [SENT] I wo n't shut up about it to my wife and have yet to locate it
# 1481                                                                                                                                                             [SENT] Protect D here we come !!
# 1483                                                                                                                                           [SENT] Yes the 4 yard pass to Adam ’s will save us
# 1489                                                                                                                       [SENT] Wentz has a rep for throwing interceptions in crucial moments 👀
#
#                                                                                                                                                                                                                            context
# 1                                                                    **IN-GROUP**: Panthers || **OUT-GROUP**: Texans || **LIVE-SCORE**: Texans 0-7 Panthers || **GAME-DATE**: 2021-09-23 || **PARENT COMMENT**: No parent comment.
# 10                                                                       **IN-GROUP**: Patriots || **OUT-GROUP**: Jets || **LIVE-SCORE**: Patriots 3-3 Jets || **GAME-DATE**: 2022-11-20 || **PARENT COMMENT**: No parent comment.
# 17                                                                          **IN-GROUP**: Jets || **OUT-GROUP**: Ravens || **LIVE-SCORE**: Jets 3-24 Ravens || **GAME-DATE**: 2022-09-11 || **PARENT COMMENT**: No parent comment.
# 18                                                                   **IN-GROUP**: Raiders || **OUT-GROUP**: Ravens || **LIVE-SCORE**: Raiders 10-17 Ravens || **GAME-DATE**: 2021-09-13 || **PARENT COMMENT**: No parent comment.
# 22                                               **IN-GROUP**: Bills || **OUT-GROUP**: Rams || **LIVE-SCORE**: Rams 10-17 Bills || **GAME-DATE**: 2022-09-08 || **PARENT COMMENT**: Coming in VERY late - what happened to Oliver?
# ...                                                                                                                                                                                                                            ...
# 1475                                                             **IN-GROUP**: Chargers || **OUT-GROUP**: Seahawks || **LIVE-SCORE**: Chargers 0-0 Seahawks || **GAME-DATE**: 2022-10-23 || **PARENT COMMENT**: No parent comment.
# 1476                                                                **IN-GROUP**: Steelers || **OUT-GROUP**: Ravens || **LIVE-SCORE**: Steelers 7-13 Ravens || **GAME-DATE**: 2022-12-11 || **PARENT COMMENT**: No parent comment.
# 1481                                                             **IN-GROUP**: Vikings || **OUT-GROUP**: Patriots || **LIVE-SCORE**: Vikings 33-26 Patriots || **GAME-DATE**: 2022-11-24 || **PARENT COMMENT**: No parent comment.
# 1483                                                                   **IN-GROUP**: Packers || **OUT-GROUP**: 49Ers || **LIVE-SCORE**: Packers 10-10 49Ers || **GAME-DATE**: 2022-01-22 || **PARENT COMMENT**: No parent comment.
# 1489  **IN-GROUP**: Eagles || **OUT-GROUP**: Vikings || **LIVE-SCORE**: Eagles 24-7 Vikings || **GAME-DATE**: 2022-09-19 || **PARENT COMMENT**: He better Blitz like crazy next weekend. Commander Carson has cones for a Oline 😂.
#
# [318 rows x 5 columns]

# %%
annotations = []
files = glob('thresh-internal/crowd/annotations*.json')
for file in files:
    with open(file, 'r', encoding='utf-8') as f:
        new_anns = json.load(f)
        for f in new_anns:
            f['user'] = file.split('-')[1][1]
        annotations += new_anns

done_ids = []
for ann in tqdm(annotations):
    # ann_df['post_id'].append(ann['post_id'])
    done_ids.append(ann['comment_id'])

done_ids = list(set(done_ids))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 250/250 [00:00<00:00, 2716518.13it/s]

# %%
final = final.loc[~final.comment_id.isin(done_ids)].reset_index(drop=True)

# %%
final.iloc[50:100]
# Out:
#    split  post_id comment_id  \
# 50  test  100nsti    j2j3tv3
# 51  test   xbnazb    io0ve0e
# 52  test   qosg7q    hjpy1f7
# 53  test  106t8ta    j3jcunk
# 54  test   rp0uym    hq26rqh
# 55  test   xog9do    iq22vz7
# 56  test   xo2afg    ipx7elr
# 57  test   qjt4ao    hisjqsn
# 58  test   q5ex2d    hg5eorj
# 59  test   xhkdm7    ioypmp7
# 60  test  106udpv    j3jhhx8
# 61  test   q5f7n2    hg5slmn
# 62  test   z0k2o8    ix6n2o8
# 63  test   z7ecmb    iy6ag48
# 64  test   pmvgnj    hcl15ls
# 65  test   xtsbcu    iqsfpwa
# 66  test  100tod1    j2jubw1
# 67  test   prevz6    hdinzvu
# 68  test   zu9d5y    j1iqkkj
# 69  test   qi08vc    higjg47
# 70  test  106o1ov    j3i2vz9
# 71  test   pre3bz    hdiw9qb
# 72  test   r9oi5p    hnebls0
# 73  test   zumefq    j1krwwv
# 74  test   yvhapi    iwepdfh
# 75  test   rlrl3b    hpidaum
# 76  test   qa1k84    hh09sr5
# 77  test   yis1y8    iukf3oz
# 78  test   pmw615    hclefbm
# 79  test   pvwmwm    hed8rtu
# 80  test   qowzos    hjqf0ph
# 81  test   sruvzl    hwugd3s
# 82  test   xoz9be    iq1s6h0
# 83  test   xhkenx    ioyfnem
# 84  test   z0937l    ix4ohjd
# 85  test   rlrhnv    hpi1pbc
# 86  test   ybqjno    itifazd
# 87  test   xbmrln    io11jhr
# 88  test   zvaiz2    j1ogh3o
# 89  test   s5krtl    hsyusm6
# 90  test   y6pxw6    isqwi0n
# 91  test   qazn9w    hh6dfnq
# 92  test   pvwn2i    hedmkul
# 93  test   sgkus2    huxuye6
# 94  test   rzfa35    hrv7hyv
# 95  test   r48vv2    hmfzt75
# 96  test   y9dkvu    it5dxqx
# 97  test   xtttgm    iqs245b
# 98  test   q0p5xt    hfaa5jd
# 99  test   qtv35q    hkmxlzr
#
#                                                                                                                                                                                                                                                 source  \
# 50                                                                                                                                            [SENT] wow who could 've guessed the result of that kick ? [SENT] did n't even glance over from my meal
# 51                                                                                                                                                                                        [SENT] Okay , that 's it fire everyone in this organization
# 52                                                                                                                                                                 [SENT] This team is weak and it all stems from the head coach . [SENT] Fire Zimmer
# 53                                                                                                                                                                                                                      [SENT] winning cures all lmao
# 54                                                                                                                                         [SENT] The streak is in jeopardy because McVay is forcing the pass when his QB is having a terrible game .
# 55                                                                                                                                                                                                                                  [SENT] You should
# 56                                                                                                                                                                                                                         [SENT] Was that on Jimmy ?
# 57                                                                                          [SENT] You do n't " come back healthy " from this injury in the same season . [SENT] If he 's out , he 's done for the year because it requires surgery .
# 58                                                                                               [SENT] He blocks well and he draws double teams to open up others ( like that Higgins td ) but it ’s definitely not the impact you need from a WR1 .
# 59                                                                                                                                                                                                                          [SENT] Pats so lucky haha
# 60                                                                                                                                                                                                      [SENT] Glad I 'm not the only one seeing it .
# 61                                                                                                                                       [SENT] Dude he challenged to give his defense a break . [SENT] That was a very necessary long timeout needed
# 62                                                                                                                                                                                                  [SENT] Pat needs to get rid of the ball there tho
# 63  [SENT] Steelers moved easily down the field for 3 on first drive ( rare Kenny stop on 3rd down ) . [SENT] Ryan promptly threw a Wentz -esq pick . [SENT] Yannick got back to back sacks and forced a punt . [SENT] Ryan sucks and we punted again
# 64                                                                                                                                                             [SENT] Well if we get our shit together not get flagged we actually look pretty decent
# 65                                                                                                                                                                                                         [SENT] chargers can NEVER finish a game ..
# 66                                                                                                                                                                                                                  [SENT] Ghost of Devin Hester ....
# 67                                                                                                                                                                                        [SENT] Really happy for AJ Green . [SENT] Needed that badly
# 68                                                                                                                                                                               [SENT] Damn the chiefs had a harder time scoring on us than that wth
# 69                                                                                                                                                                                                                  [SENT] Maybe our Defense is legit
# 70                                                                                                                                                                                           [SENT] There are many people on this sub who would agree
# 71                                                                                                                               [SENT] Why use a time out there ? [SENT] I ’d rather have the ball at 1:50 and two timeout than 2:10 and 1 timeout .
# 72                                                                                                                                                                                                                        [SENT] Lmao . [SENT] Soft .
# 73                                                                                                                                                                                                                    [SENT] heck of a play by sutton
# 74                                                                                                               [SENT] I 'm glad someone agrees . [SENT] He 's not the decisive runner I expected after hearing them rave about him all off - season
# 75                                                                                                                               [SENT] RW ensured Ramsey had what look like a great game when in reality he had one of his worst games covering DK .
# 76                                                                                                                                                                                                                    [SENT] Jackson is garbage man .
# 77                                                                                                                                                                     [SENT] Trent Irwin is on the field ! [SENT] Hell yea . [SENT] Dude can catch .
# 78                                                                                                                                                                                       [SENT] Some times you just have to call it like you see it .
# 79                                                                                                                                                                                                                [SENT] Nice checkdown and play call
# 80                                                                                                                                                                                                                                  [SENT] Or penalty
# 81                                                                                                                                                                                                      [SENT] Anyone can do tht by grabbing a jersey
# 82                                                                                                                                                                                                                             [SENT] A LASER FROM DJ
# 83                                                                                                                                                   [SENT] Being competitive would be nice . [SENT] Nobody expected complete domination by the Lions
# 84                                                             [SENT] Did n’t like the look they had for whatever Play they had called so they kicked the FG . [SENT] I actually do n’t mind it in this game where winner will probably have 9 points
# 85                                                                                                                                                           [SENT] Jake Elliot better make the Pro Bowl . [SENT] He 's having an incredible season .
# 86                                                                                                                                                                                     [SENT] It would be just sooooooooooooo 49ers to not score here
# 87                                                                                                                                                              [SENT] For reals ! [SENT] We should try it for the first 3 quarters too next game ! 😋
# 88                                                                                                                                                                                                 [SENT] We need to get some bring back arians signs
# 89                                                                                                                                                                                     [SENT] Issue with drops , and he ’s not your prototypical wr .
# 90                                                                                                                                         [SENT] They caught them in a bad look with that hurry up . [SENT] They should have called timeout to reset
# 91                                                                                                                                   [SENT] WHAT TOP 5 YOU SMOKIN ON ? [SENT] MY TOP FIVE IS : 1 . LANDRY 2 . LANDRY 3 . LANDRY 4 . LANDRY 5 . LANDRY
# 92                                                                                                                                                                                     [SENT] Mac Jones is going to die against that Bucs D is n't he
# 93                                                                                                              [SENT] If they lose this , Shanahan needs to go . [SENT] Fuck this conservative play calling when you have a chance to go for the win
# 94                                                                                                                                        [SENT] the run was killing it . [SENT] the pass needs to be a surprise . [SENT] run needs to be on repeat .
# 95                                                                                                                                                                                                    [SENT] Mac does n’t know how to throw it away .
# 96                                                                                                                                                                                                               [SENT] Certified Andy Dalton™ Moment
# 97                                                                                                                                                                                                                     [SENT] aJ wAs A bEtTeR bLoCkEr
# 98                                                                                                                                                                                                             [SENT] Holy shit they called holding !
# 99                                                                                                                                                                                                  [SENT] Sweet . [SENT] Extra TO . [SENT] Thank you
#
#                                                                                                                                                                                                                                                                                                                 context
# 50                                                                                                                                                **IN-GROUP**: Buccaneers || **OUT-GROUP**: Panthers || **LIVE-SCORE**: Buccaneers 0-7 Panthers || **GAME-DATE**: 2023-01-01 || **PARENT COMMENT**: No parent comment.
# 51                                                                                                                                                               **IN-GROUP**: Bears || **OUT-GROUP**: 49Ers || **LIVE-SCORE**: Bears 0-10 49Ers || **GAME-DATE**: 2022-09-11 || **PARENT COMMENT**: No parent comment.
# 52                                                                                                                                                        **IN-GROUP**: Vikings || **OUT-GROUP**: Ravens || **LIVE-SCORE**: Ravens 31-24 Vikings || **GAME-DATE**: 2021-11-07 || **PARENT COMMENT**: No parent comment.
# 53  **IN-GROUP**: Chargers || **OUT-GROUP**: Broncos || **LIVE-SCORE**: Broncos 24-20 Chargers || **GAME-DATE**: 2023-01-08 || **PARENT COMMENT**: I guess staley has a point lol. If we bench players and can't find our rhythm against the Jags, we'll question Staley's decision. Staley gets blamed either way lmao
# 54                                                                                                                         **IN-GROUP**: Rams || **OUT-GROUP**: Vikings || **LIVE-SCORE**: Vikings 10-13 Rams || **GAME-DATE**: 2021-12-26 || **PARENT COMMENT**: The streak is in jeopardy because of Stafford's brain
# 55                                                                                                                                                    **IN-GROUP**: Cowboys || **OUT-GROUP**: Giants || **LIVE-SCORE**: Giants 13-20 Cowboys || **GAME-DATE**: 2022-09-26 || **PARENT COMMENT**: I take back everything
# 56                                                                                                                                                                                                                                                                       Series([], Name: clean_comment, dtype: object)
# 57                         **IN-GROUP**: Browns || **OUT-GROUP**: Steelers || **LIVE-SCORE**: Browns 3-3 Steelers || **GAME-DATE**: 2021-10-31 || **PARENT COMMENT**: Mayfield looks horrible. It’s obvious he is hurt. Keenum gives us a better chance to win. Let baker heal so he can come back and win a SB healthy
# 58                                                                                                           **IN-GROUP**: Browns || **OUT-GROUP**: Chargers || **LIVE-SCORE**: Chargers 13-10 Browns || **GAME-DATE**: 2021-10-10 || **PARENT COMMENT**: Someone explain to me what obj has done to benefit this team.
# 59                                                                                                                                                   **IN-GROUP**: Patriots || **OUT-GROUP**: Steelers || **LIVE-SCORE**: Steelers 6-10 Patriots || **GAME-DATE**: 2022-09-18 || **PARENT COMMENT**: No parent comment.
# 60                                                                                        **IN-GROUP**: Eagles || **OUT-GROUP**: Giants || **LIVE-SCORE**: Eagles 22-9 Giants || **GAME-DATE**: 2023-01-08 || **PARENT COMMENT**: Anybody else feel like the refs are shorting our yardage and giving a lil extra to ny
# 61                                                                                                                        **IN-GROUP**: Bears || **OUT-GROUP**: Raiders || **LIVE-SCORE**: Raiders 9-14 Bears || **GAME-DATE**: 2021-10-10 || **PARENT COMMENT**: Glad we wasted a challenge on that bullshit 4th down.
# 62                                                                                                                                                      **IN-GROUP**: Chiefs || **OUT-GROUP**: Chargers || **LIVE-SCORE**: Chargers 20-16 Chiefs || **GAME-DATE**: 2022-11-20 || **PARENT COMMENT**: No parent comment.
# 63                                                      **IN-GROUP**: Colts || **OUT-GROUP**: Steelers || **LIVE-SCORE**: Colts 0-3 Steelers || **GAME-DATE**: 2022-11-28 || **PARENT COMMENT**: Hey I’m not home yet and haven’t seen anything can someone update me on the shitshow that is colts prime time football
# 64                                                                                                                                                        **IN-GROUP**: Vikings || **OUT-GROUP**: Bengals || **LIVE-SCORE**: Bengals 0-0 Vikings || **GAME-DATE**: 2021-09-12 || **PARENT COMMENT**: No parent comment.
# 65                                                                                                                                                      **IN-GROUP**: Chargers || **OUT-GROUP**: Texans || **LIVE-SCORE**: Texans 21-27 Chargers || **GAME-DATE**: 2022-10-02 || **PARENT COMMENT**: No parent comment.
# 66                                                                                                                                                        **IN-GROUP**: Packers || **OUT-GROUP**: Vikings || **LIVE-SCORE**: Packers 7-3 Vikings || **GAME-DATE**: 2023-01-01 || **PARENT COMMENT**: No parent comment.
# 67                                                                                                                                                  **IN-GROUP**: Cardinals || **OUT-GROUP**: Vikings || **LIVE-SCORE**: Cardinals 31-30 Vikings || **GAME-DATE**: 2021-09-19 || **PARENT COMMENT**: No parent comment.
# 68                                                                                                                                                                **IN-GROUP**: Bills || **OUT-GROUP**: Bears || **LIVE-SCORE**: Bears 7-0 Bills || **GAME-DATE**: 2022-12-24 || **PARENT COMMENT**: No parent comment.
# 69                                                                                                                                  **IN-GROUP**: Packers || **OUT-GROUP**: Cardinals || **LIVE-SCORE**: Cardinals 7-10 Packers || **GAME-DATE**: 2021-10-28 || **PARENT COMMENT**: I think maybe Arizona is fraudulent
# 70                                                                 **IN-GROUP**: Patriots || **OUT-GROUP**: Bills || **LIVE-SCORE**: Bills 14-7 Patriots || **GAME-DATE**: 2023-01-08 || **PARENT COMMENT**: This whole season has made me realize the best way to resurrect this team's offense.  Bring. Back. N'Keal.
# 71                                                                                                                                                  **IN-GROUP**: Vikings || **OUT-GROUP**: Cardinals || **LIVE-SCORE**: Cardinals 34-33 Vikings || **GAME-DATE**: 2021-09-19 || **PARENT COMMENT**: No parent comment.
# 72                                                                                                                                                        **IN-GROUP**: 49Ers || **OUT-GROUP**: Seahawks || **LIVE-SCORE**: Seahawks 30-23 49Ers || **GAME-DATE**: 2021-12-05 || **PARENT COMMENT**: No parent comment.
# 73                                                                                                                                                    **IN-GROUP**: Steelers || **OUT-GROUP**: Raiders || **LIVE-SCORE**: Steelers 13-10 Raiders || **GAME-DATE**: 2022-12-24 || **PARENT COMMENT**: No parent comment.
# 74                                                                                                 **IN-GROUP**: Commanders || **OUT-GROUP**: Eagles || **LIVE-SCORE**: Eagles 14-10 Commanders || **GAME-DATE**: 2022-11-14 || **PARENT COMMENT**: Hasn't impressed me either really. Gibson has been markedly better.
# 75                                                                                                                                                          **IN-GROUP**: Seahawks || **OUT-GROUP**: Rams || **LIVE-SCORE**: Rams 20-10 Seahawks || **GAME-DATE**: 2021-12-21 || **PARENT COMMENT**: No parent comment.
# 76                                                                                                                                                **IN-GROUP**: Commanders || **OUT-GROUP**: Washington || **LIVE-SCORE**: Commanders 3-7 Chiefs || **GAME-DATE**: 2021-10-17 || **PARENT COMMENT**: No parent comment.
# 77                                                                                                                                                        **IN-GROUP**: Bengals || **OUT-GROUP**: Browns || **LIVE-SCORE**: Browns 32-13 Bengals || **GAME-DATE**: 2022-10-31 || **PARENT COMMENT**: No parent comment.
# 78                                                                                                     **IN-GROUP**: Jaguars || **OUT-GROUP**: Texans || **LIVE-SCORE**: Texans 20-7 Jaguars || **GAME-DATE**: 2021-09-12 || **PARENT COMMENT**: Their kicker has a nice ass- sorry I’m a straight female can’t help it
# 79                                                                                                                                                          **IN-GROUP**: Giants || **OUT-GROUP**: Falcons || **LIVE-SCORE**: Giants 0-0 Falcons || **GAME-DATE**: 2021-09-26 || **PARENT COMMENT**: No parent comment.
# 80                                                                **IN-GROUP**: 49Ers || **OUT-GROUP**: Cardinals || **LIVE-SCORE**: 49Ers 0-17 Cardinals || **GAME-DATE**: 2021-11-07 || **PARENT COMMENT**: Whenever we have a play that goes more than ten yards, I’m just holding my breath waiting for the fumble.
# 81                                                                                                                                              **IN-GROUP**: Rams || **OUT-GROUP**: Bengals || **LIVE-SCORE**: Bengals 3-7 Rams || **GAME-DATE**: 2022-02-13 || **PARENT COMMENT**: Look who made the stop lmao casual
# 82                                                                                                                                                          **IN-GROUP**: Giants || **OUT-GROUP**: Cowboys || **LIVE-SCORE**: Giants 3-6 Cowboys || **GAME-DATE**: 2022-09-26 || **PARENT COMMENT**: No parent comment.
# 83     **IN-GROUP**: Commanders || **OUT-GROUP**: Lions || **LIVE-SCORE**: Lions 15-0 Commanders || **GAME-DATE**: 2022-09-18 || **PARENT COMMENT**: In convinced People on this sub have no knowledge of football, The LIONS d line did this t a top 3-5 o line last week to the eagles, wtf did they expect this week
# 84                                                                                                     **IN-GROUP**: Patriots || **OUT-GROUP**: Jets || **LIVE-SCORE**: Patriots 3-0 Jets || **GAME-DATE**: 2022-11-20 || **PARENT COMMENT**: How the fuck did we have an entire break and come back to call a timeout?
# 85                                                                                                                                                  **IN-GROUP**: Eagles || **OUT-GROUP**: Washington || **LIVE-SCORE**: Eagles 10-10 Commanders || **GAME-DATE**: 2021-12-21 || **PARENT COMMENT**: No parent comment.
# 86                                                                                                                                                            **IN-GROUP**: 49Ers || **OUT-GROUP**: Chiefs || **LIVE-SCORE**: 49Ers 13-14 Chiefs || **GAME-DATE**: 2022-10-23 || **PARENT COMMENT**: No parent comment.
# 87                                                                                                                      **IN-GROUP**: Panthers || **OUT-GROUP**: Browns || **LIVE-SCORE**: Panthers 14-20 Browns || **GAME-DATE**: 2022-09-11 || **PARENT COMMENT**: THIS IS WHAT CAN HAPPEN WHEN YOU RUN THE DAMN BALL
# 88                                                                                                                                              **IN-GROUP**: Buccaneers || **OUT-GROUP**: Cardinals || **LIVE-SCORE**: Cardinals 3-6 Buccaneers || **GAME-DATE**: 2022-12-25 || **PARENT COMMENT**: No parent comment.
# 89                                                                                **IN-GROUP**: 49Ers || **OUT-GROUP**: Cowboys || **LIVE-SCORE**: Cowboys 7-23 49Ers || **GAME-DATE**: 2022-01-16 || **PARENT COMMENT**: My understanding is that Debo had a good college career. How the fuck did he drop to Round 2?
# 90                                                                                                                                                     **IN-GROUP**: Broncos || **OUT-GROUP**: Chargers || **LIVE-SCORE**: Chargers 7-10 Broncos || **GAME-DATE**: 2022-10-17 || **PARENT COMMENT**: No parent comment.
# 91                                                                                                                                                              **IN-GROUP**: Titans || **OUT-GROUP**: Bills || **LIVE-SCORE**: Titans 0-3 Bills || **GAME-DATE**: 2021-10-18 || **PARENT COMMENT**: No parent comment.
# 92                                                                                                                                                       **IN-GROUP**: Patriots || **OUT-GROUP**: Saints || **LIVE-SCORE**: Patriots 3-14 Saints || **GAME-DATE**: 2021-09-26 || **PARENT COMMENT**: No parent comment.
# 93                                                                                                                                                                **IN-GROUP**: 49Ers || **OUT-GROUP**: Rams || **LIVE-SCORE**: Rams 17-17 49Ers || **GAME-DATE**: 2022-01-30 || **PARENT COMMENT**: No parent comment.
# 94                                                                                                                                                        **IN-GROUP**: Eagles || **OUT-GROUP**: Cowboys || **LIVE-SCORE**: Eagles 20-30 Cowboys || **GAME-DATE**: 2022-01-08 || **PARENT COMMENT**: No parent comment.
# 95                                                                                                                                                      **IN-GROUP**: Patriots || **OUT-GROUP**: Titans || **LIVE-SCORE**: Patriots 26-13 Titans || **GAME-DATE**: 2021-11-28 || **PARENT COMMENT**: No parent comment.
# 96                                                                                                                                                    **IN-GROUP**: Cardinals || **OUT-GROUP**: Saints || **LIVE-SCORE**: Cardinals 20-14 Saints || **GAME-DATE**: 2022-10-20 || **PARENT COMMENT**: No parent comment.
# 97                                                                                                                                                             **IN-GROUP**: Titans || **OUT-GROUP**: Colts || **LIVE-SCORE**: Colts 3-17 Titans || **GAME-DATE**: 2022-10-02 || **PARENT COMMENT**: No parent comment.
# 98                                                                                                                                                        **IN-GROUP**: Seahawks || **OUT-GROUP**: 49Ers || **LIVE-SCORE**: 49Ers 13-28 Seahawks || **GAME-DATE**: 2021-10-03 || **PARENT COMMENT**: No parent comment.
# 99                                                                                                                                                          **IN-GROUP**: Jaguars || **OUT-GROUP**: Colts || **LIVE-SCORE**: Colts 23-17 Jaguars || **GAME-DATE**: 2021-11-14 || **PARENT COMMENT**: No parent comment.

# %%
final.shape
# Out:
# (293, 5)

# %%
with open('thresh-internal/crowd/test/sample-6.json', 'w') as f:
    final.iloc[250:300].to_json(f, orient='records', indent=4)
